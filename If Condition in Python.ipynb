# %% [markdown]
# # Python If Condition

# %%
num= input("Enter a int vaulue: ")
num= int(num)
if num%2 == 0:
    print(f"{num} is even number")
else:
    print(f"{num} is odd number")
# Out:
# Enter a int vaulue: 45
# 45 is odd number

# %% [markdown]
# # Exercise: Python If Condition

# %% [markdown]
# Using following list of cities per country,
#
# india = ["mumbai", "banglore", "chennai", "delhi"]
#
# pakistan = ["lahore","karachi","islamabad"]
#
# bangladesh = ["dhaka", "khulna", "rangpur"]
#
# 1. Write a program that asks user to enter a city name and it should tell which country the city belongs to
# 2. Write a program that asks user to enter two cities and it tells you if they both are in same country or not. For example if I enter mumbai and chennai, it will print "Both cities are in India" but if I enter mumbai and dhaka it should print "They don't belong to same country"

# %%
india = ["mumbai", "banglore", "chennai", "delhi"]
pakistan = ["lahore","karachi","islamabad"]
bangladesh = ["dhaka", "khulna", "rangpur"]
#Write a program that asks user to enter a city name and it should tell which country the city belongs to
city = input("Type your city name here: ")
if city in india:
    print(f"{city} is a city of India")
elif city in pakistan:
    print(f"{city} is a city of Pakistan")
elif city in bangladesh:
    print(f"{city} is a city of Bangladesh")
else:
    print(f"based on my program i wont be able to tell you which city is this :", city)
    
#Write a program that asks user to enter two cities and it tells you if they both are in same country or not. 
#For example if I enter mumbai and chennai, it will print "Both cities are in India" 
#but if I enter mumbai and dhaka it should print "They don't belong to same country"

fCity= input('Type your First city name: ')
sCity= input('Type your 2nd city name: ')

if fCity and sCity in india:
    print('Both cities are in India')
else:
    print('They don\'t belong to same country')
# Out:
# Type your city name here: mubai
# based on my program i wont be able to tell you which city is this : mubai
# Type your First city name: 454
# Type your 2nd city name: 54
# They don't belong to same country

# %% [markdown]
# Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
# Ask user to enter his fasting sugar level
# If it is below 80 to 100 range then print that sugar is low
# If it is above 100 then print that it is high otherwise print that it is normal

# %%
sugar = input("input your sugar level: ")
sugar= float(sugar)
if sugar>100:
    print("Your sugar level is high")
elif sugar<80:
    print("Your sugar Level is low")
else:
    print("your sugar level is normal")
